# %%
import os
import streamlit as st
import pdfplumber
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import openai
from langdetect import detect
from nltk.tokenize import sent_tokenize

# Initialize OpenAI API key
openai.api_key = os.getenv("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")

# Load the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Streamlit UI for the chatbot
st.set_page_config(page_title="Document-Based Chatbot", layout="wide")

st.title("Document-Based Question Answering Chatbot")
st.markdown("Upload your documents and ask questions!")

# Sidebar for translation option
with st.sidebar:
    st.header("Translation Options")
    translate_option = st.radio("Would you like to translate responses?", ('No', 'Yes'))
    target_language = st.selectbox("Select target language", ['French', 'Spanish', 'German']) if translate_option == 'Yes' else None

# Initialize session state for the chat history
if 'chat_history' not in st.session_state:
    st.session_state['chat_history'] = []

# File Uploader
uploaded_files = st.file_uploader("Upload PDF documents", type=["pdf"], accept_multiple_files=True)

# Function to extract text from PDFs
@st.cache
def extract_text_from_pdfs(files):
    documents = {}
    for file in files:
        with pdfplumber.open(file) as pdf:
            full_text = ""
            for page in pdf.pages:
                full_text += page.extract_text()
            documents[file.name] = full_text
    return documents

# Function to chunk the text into smaller segments
def chunk_text_for_all_docs(documents, max_tokens=500):
    all_chunks = {}
    for filename, text in documents.items():
        sentences = sent_tokenize(text)
        chunks = []
        chunk = []
        tokens_count = 0
        for sentence in sentences:
            tokens = len(sentence.split())
            if tokens_count + tokens > max_tokens:
                chunks.append(" ".join(chunk))
                chunk = []
                tokens_count = 0
            chunk.append(sentence)
            tokens_count += tokens
        if chunk:
            chunks.append(" ".join(chunk))
        all_chunks[filename] = chunks
    return all_chunks

# Function to generate embeddings
def generate_embeddings_for_all_docs(all_chunks):
    all_embeddings = {}
    embedding_ids = []
    chunk_count = 0
    for filename, chunks in all_chunks.items():
        embeddings = model.encode(chunks, convert_to_tensor=False)
        all_embeddings[filename] = embeddings
        for i, chunk in enumerate(chunks):
            embedding_ids.append(f"{filename}-chunk-{i}")
            chunk_count += 1
    return all_embeddings, embedding_ids

# Function to create FAISS index
def create_faiss_index(embeddings):
    dimension = embeddings[next(iter(embeddings))][0].shape[0]  # Embedding size
    index = faiss.IndexFlatL2(dimension)  # L2 distance index
    all_embedding_list = []
    for embedding_list in embeddings.values():
        all_embedding_list.extend(embedding_list)
    index.add(np.array(all_embedding_list))
    return index

# Function to query FAISS
def query_faiss(query, all_chunks, index, embedding_ids, top_k=3):
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding), top_k)
    retrieved_chunks = [all_chunks[embedding_ids[i].split('-chunk-')[0]][int(embedding_ids[i].split('-chunk-')[-1])] for i in I[0]]
    return retrieved_chunks

# Function to generate a response from GPT-3.5
def generate_response_with_context(query, retrieved_chunks):
    prompt = f"User query: {query}\n\nRelevant information from documents:\n{retrieved_chunks}"
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=200
    )
    return response['choices'][0]['message']['content'].strip()

# Function to translate the response
def translate_text(text, target_language):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": f"Translate this text to {target_language}."},
            {"role": "user", "content": text}
        ],
        max_tokens=100
    )
    return response['choices'][0]['message']['content'].strip()

# Main section for query and responses
if uploaded_files:
    with st.spinner('Processing documents...'):
        documents = extract_text_from_pdfs(uploaded_files)
        all_chunks = chunk_text_for_all_docs(documents)
        all_embeddings, embedding_ids = generate_embeddings_for_all_docs(all_chunks)
        index = create_faiss_index(all_embeddings)
        st.success('Documents processed successfully!')

    # Continuous Chat Interface
    user_query = st.text_input("Enter your query:")

    if st.button("Submit Query") and user_query:
        retrieved_chunks = query_faiss(user_query, all_chunks, index, embedding_ids)
        response = generate_response_with_context(user_query, retrieved_chunks)
        
        # Store the chat history
        st.session_state.chat_history.append(f"You: {user_query}")
        st.session_state.chat_history.append(f"Chatbot: {response}")
        
        # Display chat history
        for msg in st.session_state.chat_history:
            st.write(msg)

        # Handle translation if enabled
        if translate_option == 'Yes' and target_language:
            translated_response = translate_text(response, target_language)
            st.write(f"Translated Response ({target_language}): {translated_response}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8592\2446277313.py in <module>
#       4 import faiss
#       5 import numpy as np
# ----> 6 from sentence_transformers import SentenceTransformer
#       7 import openai
#       8 from langdetect import detect
#
# ~\anaconda3\lib\site-packages\sentence_transformers\__init__.py in <module>
#       7 import os
#       8
# ----> 9 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#      10 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      11 from sentence_transformers.LoggingHandler import LoggingHandler
#
# ~\anaconda3\lib\site-packages\sentence_transformers\cross_encoder\__init__.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from .CrossEncoder import CrossEncoder
#       4
#       5 __all__ = ["CrossEncoder"]
#
# ~\anaconda3\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py in <module>
#       7
#       8 import numpy as np
# ----> 9 import torch
#      10 from torch import Tensor, nn
#      11 from torch.optim import Optimizer
#
# ~\anaconda3\lib\site-packages\torch\__init__.py in <module>
#     762
#     763 __name, __obj = '', None
# --> 764 for __name in dir(_C):
#     765     if __name[0] != '_' and not __name.endswith('Base'):
#     766         __all__.append(__name)
#
# NameError: name '_C' is not defined

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\ishtiyak\anaconda3\lib\site-packages (2.4.1)
# Collecting torchvision
#   Downloading torchvision-0.19.1-cp39-cp39-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 11.6 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.4.1-cp39-cp39-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: fsspec in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: sympy in c:\users\ishtiyak\anaconda3\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: numpy in c:\users\ishtiyak\anaconda3\lib\site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ishtiyak\anaconda3\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ishtiyak\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ishtiyak\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.4.1 torchvision-0.19.1
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)  # Check PyTorch version
print(torch.cuda.is_available())  # Check if CUDA is available
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8592\2801053090.py in <module>
# ----> 1 import torch
#       2 print(torch.__version__)  # Check PyTorch version
#       3 print(torch.cuda.is_available())  # Check if CUDA is available
#
# ~\anaconda3\lib\site-packages\torch\__init__.py in <module>
#     762
#     763 __name, __obj = '', None
# --> 764 for __name in dir(_C):
#     765     if __name[0] != '_' and not __name.endswith('Base'):
#     766         __all__.append(__name)
#
# NameError: name '_C' is not defined
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Ishtiyak\anaconda3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.8
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.9.24  |       haa95532_0         131 KB
#     certifi-2024.8.30          |   py39haa95532_0         163 KB
#     colorama-0.4.6             |   py39haa95532_0          32 KB
#     cuda-cccl-12.6.77          |                0          16 KB  nvidia
#     cuda-cccl_win-64-12.6.77   |                0         1.0 MB  nvidia
#     cuda-cudart-11.8.89        |                0         1.4 MB  nvidia
#     cuda-cudart-dev-11.8.89    |                0         723 KB  nvidia
#     cuda-cupti-11.8.87         |                0        11.5 MB  nvidia
#     cuda-libraries-11.8.0      |                0           1 KB  nvidia
#     cuda-libraries-dev-11.8.0  |                0           1 KB  nvidia
#     cuda-nvrtc-11.8.89         |                0        72.1 MB  nvidia
#     cuda-nvrtc-dev-11.8.89     |                0        16.1 MB  nvidia
#     cuda-nvtx-11.8.86          |                0          43 KB  nvidia
#     cuda-profiler-api-12.6.77  |                0          19 KB  nvidia
#     cuda-runtime-11.8.0        |                0           1 KB  nvidia
#     cuda-version-12.6          |                3          16 KB  nvidia
#     fsspec-2024.6.1            |   py39haa95532_0         282 KB
#     joblib-1.4.2               |   py39haa95532_0         398 KB
#     libcublas-11.11.3.6        |                0          33 KB  nvidia
#     libcublas-dev-11.11.3.6    |                0       375.9 MB  nvidia
#     libcufft-10.9.0.58         |                0           6 KB  nvidia
#     libcufft-dev-10.9.0.58     |                0       144.6 MB  nvidia
#     libcurand-10.3.7.77        |                0        41.6 MB  nvidia
#     libcurand-dev-10.3.7.77    |                0         262 KB  nvidia
#     libcusolver-11.4.1.48      |                0          29 KB  nvidia
#     libcusolver-dev-11.4.1.48  |                0        94.1 MB  nvidia
#     libcusparse-11.7.5.86      |                0          13 KB  nvidia
#     libcusparse-dev-11.7.5.86  |                0       175.7 MB  nvidia
#     libjpeg-turbo-2.0.0        |       h196d8e1_0         618 KB
#     libnpp-11.8.0.86           |                0         294 KB  nvidia
#     libnpp-dev-11.8.0.86       |                0       143.2 MB  nvidia
#     libnvjpeg-11.9.0.86        |                0           4 KB  nvidia
#     libnvjpeg-dev-11.9.0.86    |                0         1.9 MB  nvidia
#     libuv-1.44.2               |       h2bbff1b_0         288 KB
#     pygments-2.15.1            |   py39haa95532_1         1.7 MB
#     pytorch-2.3.0              |py3.9_cuda11.8_cudnn8_0        1.39 GB  pytorch
#     pytorch-cuda-11.8          |       h24eeafa_5           4 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     pytz-2024.1                |   py39haa95532_0         215 KB
#     requests-2.32.3            |   py39haa95532_0         100 KB
#     tenacity-8.2.3             |   py39haa95532_0          46 KB
#     threadpoolctl-3.5.0        |   py39h9909e9c_0          43 KB
#     torchaudio-2.3.0           |       py39_cu118         7.0 MB  pytorch
#     torchvision-0.18.0         |       py39_cu118         7.6 MB  pytorch
#     tqdm-4.66.5                |   py39h9909e9c_0         160 KB
#     ------------------------------------------------------------
#                                            Total:        2.46 GB
#
# The following NEW packages will be INSTALLED:
#
#   colorama           pkgs/main/win-64::colorama-0.4.6-py39haa95532_0
#   cuda-cccl          nvidia/win-64::cuda-cccl-12.6.77-0
#   cuda-cccl_win-64   nvidia/noarch::cuda-cccl_win-64-12.6.77-0
#   cuda-cudart        nvidia/win-64::cuda-cudart-11.8.89-0
#   cuda-cudart-dev    nvidia/win-64::cuda-cudart-dev-11.8.89-0
#   cuda-cupti         nvidia/win-64::cuda-cupti-11.8.87-0
#   cuda-libraries     nvidia/win-64::cuda-libraries-11.8.0-0
#   cuda-libraries-dev nvidia/win-64::cuda-libraries-dev-11.8.0-0
#   cuda-nvrtc         nvidia/win-64::cuda-nvrtc-11.8.89-0
#   cuda-nvrtc-dev     nvidia/win-64::cuda-nvrtc-dev-11.8.89-0
#   cuda-nvtx          nvidia/win-64::cuda-nvtx-11.8.86-0
#   cuda-profiler-api  nvidia/win-64::cuda-profiler-api-12.6.77-0
#   cuda-runtime       nvidia/win-64::cuda-runtime-11.8.0-0
#   cuda-version       nvidia/noarch::cuda-version-12.6-3
#   fsspec             pkgs/main/win-64::fsspec-2024.6.1-py39haa95532_0
#   joblib             pkgs/main/win-64::joblib-1.4.2-py39haa95532_0
#   libcublas          nvidia/win-64::libcublas-11.11.3.6-0
#   libcublas-dev      nvidia/win-64::libcublas-dev-11.11.3.6-0
#   libcufft           nvidia/win-64::libcufft-10.9.0.58-0
#   libcufft-dev       nvidia/win-64::libcufft-dev-10.9.0.58-0
#   libcurand          nvidia/win-64::libcurand-10.3.7.77-0
#   libcurand-dev      nvidia/win-64::libcurand-dev-10.3.7.77-0
#   libcusolver        nvidia/win-64::libcusolver-11.4.1.48-0
#   libcusolver-dev    nvidia/win-64::libcusolver-dev-11.4.1.48-0
#   libcusparse        nvidia/win-64::libcusparse-11.7.5.86-0
#   libcusparse-dev    nvidia/win-64::libcusparse-dev-11.7.5.86-0
#   libjpeg-turbo      pkgs/main/win-64::libjpeg-turbo-2.0.0-h196d8e1_0
#   libnpp             nvidia/win-64::libnpp-11.8.0.86-0
#   libnpp-dev         nvidia/win-64::libnpp-dev-11.8.0.86-0
#   libnvjpeg          nvidia/win-64::libnvjpeg-11.9.0.86-0
#   libnvjpeg-dev      nvidia/win-64::libnvjpeg-dev-11.9.0.86-0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.21.5-py39hca35cd5_3
#   pygments           pkgs/main/win-64::pygments-2.15.1-py39haa95532_1
#   pytorch            pytorch/win-64::pytorch-2.3.0-py3.9_cuda11.8_cudnn8_0
#   pytorch-cuda       pytorch/win-64::pytorch-cuda-11.8-h24eeafa_5
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   pytz               pkgs/main/win-64::pytz-2024.1-py39haa95532_0
#   requests           pkgs/main/win-64::requests-2.32.3-py39haa95532_0
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.0.2-py39hf11a4ad_1
#   tenacity           pkgs/main/win-64::tenacity-8.2.3-py39haa95532_0
#   threadpoolctl      pkgs/main/win-64::threadpoolctl-3.5.0-py39h9909e9c_0
#   torchaudio         pytorch/win-64::torchaudio-2.3.0-py39_cu118
#   torchvision        pytorch/win-64::torchvision-0.18.0-py39_cu118
#   tqdm               pkgs/main/win-64::tqdm-4.66.5-py39h9909e9c_0
#   typing_extensions  pkgs/main/win-64::typing_extensions-4.3.0-py39haa95532_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.08.22-haa95532_0 --> 2024.9.24-haa95532_0
#   certifi                          2023.7.22-py39haa95532_0 --> 2024.8.30-py39haa95532_0
#   openssl                                 1.1.1v-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
# joblib-1.4.2         | 398 KB    |            |   0%
#
#
# ca-certificates-2024 | 131 KB    |            |   0%
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    |            |   0%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   0%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
# libcufft-10.9.0.58   | 6 KB      |            |   0%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   |            |   0%
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
# cuda-version-12.6    | 16 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# cuda-profiler-api-12 | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.3      | 100 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 43 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2024.1          | 215 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# joblib-1.4.2         | 398 KB    | 4          |   4%
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | 2          |   3%
#
#
# ca-certificates-2024 | 131 KB    | #2         |  12%
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   0%
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   0%
#
#
# ca-certificates-2024 | 131 KB    | ########## | 100%
#
#
# ca-certificates-2024 | 131 KB    | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
# libcufft-dev-10.9.0. | 144.6 MB  | 1          |   2%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   0%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   |            |   0%
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   0%
#
#
#
#
#
#
# libcufft-10.9.0.58   | 6 KB      | ########## | 100%
#
#
#
#
#
#
# libcufft-10.9.0.58   | 6 KB      | ########## | 100%
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
#
#
#
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   1%
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   |            |   0%
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   1%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   1%
#
#
#
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   |            |   1%
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
# cuda-version-12.6    | 16 KB     | #########7 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   1%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 1          |   1%
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
# cuda-version-12.6    | 16 KB     | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   2%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   |            |   0%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 1          |   2%
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   |            |   1%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 1          |   1%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 2          |   2%
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   1%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   2%
#
# joblib-1.4.2         | 398 KB    | ########## | 100%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 3          |   3%
#
# joblib-1.4.2         | 398 KB    | ########## | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   1%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 2          |   2%
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 5          |   5%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   3%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   1%
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 8          |   8%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   1%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 4          |   5%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   3%
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #1         |  11%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 6          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   4%
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #4         |  14%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 7          |   7%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #7         |  17%
# libcufft-dev-10.9.0. | 144.6 MB  | #2         |  12%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##         |  21%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | #3         |  13%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 8          |   9%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##3        |  24%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 5          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | #4         |  14%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##6        |  27%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 5          |   6%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##9        |  30%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #          |  10%
# libcufft-dev-10.9.0. | 144.6 MB  | #4         |  15%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 5          |   6%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###2       |  32%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #1         |  11%
# libcufft-dev-10.9.0. | 144.6 MB  | #5         |  16%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   6%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###5       |  35%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #1         |  12%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   7%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###8       |  39%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #2         |  13%
# libcufft-dev-10.9.0. | 144.6 MB  | #6         |  17%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
# libcufft-dev-10.9.0. | 144.6 MB  | #7         |  17%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####1      |  41%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #3         |  13%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
# libcufft-dev-10.9.0. | 144.6 MB  | #8         |  18%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####6      |  46%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #4         |  14%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####9      |  50%
# libcufft-dev-10.9.0. | 144.6 MB  | #9         |  19%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #5         |  15%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####2     |  53%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
# libcufft-dev-10.9.0. | 144.6 MB  | #9         |  20%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #5         |  16%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   2%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####6     |  56%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #6         |  17%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####9     |  60%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
# libcufft-dev-10.9.0. | 144.6 MB  | ##         |  20%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #7         |  17%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######3    |  63%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
# libcufft-dev-10.9.0. | 144.6 MB  | ##1        |  22%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #8         |  18%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######6    |  66%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #9         |  19%
# libcufft-dev-10.9.0. | 144.6 MB  | ##2        |  22%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######9    |  69%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #9         |  20%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
# libcufft-dev-10.9.0. | 144.6 MB  | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######2   |  73%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##         |  21%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######5   |  76%
# libcufft-dev-10.9.0. | 144.6 MB  | ##3        |  24%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##1        |  22%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######9   |  79%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##2        |  23%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
# libcufft-dev-10.9.0. | 144.6 MB  | ##4        |  24%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########2  |  82%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##3        |  23%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
# libcufft-dev-10.9.0. | 144.6 MB  | ##5        |  25%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########5  |  86%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
# libcufft-dev-10.9.0. | 144.6 MB  | ##5        |  26%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########9  |  90%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##5        |  25%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
# libcufft-dev-10.9.0. | 144.6 MB  | ##6        |  26%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########2 |  93%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##6        |  26%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
# libcufft-dev-10.9.0. | 144.6 MB  | ##6        |  27%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##6        |  27%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########6 |  96%
# libcufft-dev-10.9.0. | 144.6 MB  | ##7        |  27%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  14%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########9 | 100%
# libcufft-dev-10.9.0. | 144.6 MB  | ##7        |  28%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   3%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #4         |  14%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##8        |  29%
# libcufft-dev-10.9.0. | 144.6 MB  | ##8        |  28%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
# cuda-profiler-api-12 | 19 KB     | ########4  |  84%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
# cuda-profiler-api-12 | 19 KB     | ########## | 100%
# libcufft-dev-10.9.0. | 144.6 MB  | ##8        |  29%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #4         |  15%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###        |  31%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    |            |   0%
# libcufft-dev-10.9.0. | 144.6 MB  | ##9        |  29%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #5         |  15%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | 7          |   8%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
# libcufft-dev-10.9.0. | 144.6 MB  | ###        |  30%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###2       |  33%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | #4         |  14%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
# libcufft-dev-10.9.0. | 144.6 MB  | ###        |  31%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###3       |  34%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ##3        |  24%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
# libcufft-dev-10.9.0. | 144.6 MB  | ###1       |  31%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###4       |  35%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ###2       |  32%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 3          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #7         |  17%
# libcufft-dev-10.9.0. | 144.6 MB  | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ####       |  41%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###5       |  36%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
# libcufft-dev-10.9.0. | 144.6 MB  | ###2       |  32%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ####9      |  49%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###7       |  37%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | #####7     |  57%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###8       |  38%
# libcufft-dev-10.9.0. | 144.6 MB  | ###2       |  33%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #8         |  18%
# libcufft-dev-10.9.0. | 144.6 MB  | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ######5    |  66%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ###9       |  39%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #8         |  19%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | #######3   |  73%
# libcufft-dev-10.9.0. | 144.6 MB  | ###4       |  34%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #9         |  19%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ########1  |  81%
# libcufft-dev-10.9.0. | 144.6 MB  | ###4       |  35%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #9         |  20%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ########9  |  89%
# libcufft-dev-10.9.0. | 144.6 MB  | ###5       |  35%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##         |  20%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | #########6 |  97%
# libcufft-dev-10.9.0. | 144.6 MB  | ###5       |  36%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##         |  20%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####4      |  45%
# libcufft-dev-10.9.0. | 144.6 MB  | ###6       |  36%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##         |  21%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####6      |  46%
# libcufft-dev-10.9.0. | 144.6 MB  | ###6       |  37%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##1        |  21%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####7      |  47%
# libcufft-dev-10.9.0. | 144.6 MB  | ###7       |  37%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    |            |   1%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##1        |  22%
# libcufft-dev-10.9.0. | 144.6 MB  | ###7       |  38%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ##8        |  28%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####8      |  49%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##2        |  22%
# libcufft-dev-10.9.0. | 144.6 MB  | ###8       |  38%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | #####6     |  56%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ####9      |  50%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########   |  80%
# libcufft-dev-10.9.0. | 144.6 MB  | ###8       |  39%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####      |  51%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##3        |  23%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####1     |  52%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ###9       |  39%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.3      | 100 KB    | #5         |  16%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####3     |  53%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 4          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ####       |  40%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 43 KB     | ###7       |  37%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####4     |  54%
# libcufft-dev-10.9.0. | 144.6 MB  | ####       |  41%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##4        |  25%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####5     |  56%
# libcufft-dev-10.9.0. | 144.6 MB  | ####1      |  41%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     | ####9      |  49%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ####1      |  42%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####6     |  57%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2024.1          | 215 KB    | 7          |   7%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ####2      |  42%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####8     |  58%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##6        |  26%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ####2      |  43%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #####9     |  60%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########## | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
# libcufft-dev-10.9.0. | 144.6 MB  | ####3      |  43%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######1    |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##7        |  27%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.3      | 100 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.3      | 100 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ####3      |  44%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######2    |  62%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##7        |  28%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 43 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 43 KB     | ########## | 100%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ####4      |  44%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##8        |  29%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ####5      |  45%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######6    |  66%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##9        |  29%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######7    |  67%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ##9        |  30%
# libcufft-dev-10.9.0. | 144.6 MB  | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ######8    |  69%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###        |  30%
# libcufft-dev-10.9.0. | 144.6 MB  | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######    |  70%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###        |  30%
# libcufft-dev-10.9.0. | 144.6 MB  | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ####7      |  47%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###        |  31%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ####7      |  48%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | ####8      |  48%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###1       |  32%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###2       |  32%
# libcufft-dev-10.9.0. | 144.6 MB  | ####8      |  49%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###2       |  33%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 5          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | ####9      |  49%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###3       |  33%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | ####9      |  50%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########   |  80%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####      |  50%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########1  |  82%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | #####      |  51%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | #####1     |  51%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###4       |  35%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########4  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
# libcufft-dev-10.9.0. | 144.6 MB  | #####1     |  52%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###5       |  36%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####2     |  52%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###6       |  36%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####2     |  53%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###6       |  37%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | ########8  |  89%
# libcufft-dev-10.9.0. | 144.6 MB  | #####3     |  53%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###7       |  37%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########  |  90%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###7       |  38%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###8       |  39%
# libcufft-dev-10.9.0. | 144.6 MB  | #####4     |  54%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ###9       |  40%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########5 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2024.1          | 215 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2024.1          | 215 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####       |  40%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########6 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####       |  41%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########8 |  98%
# libcufft-dev-10.9.0. | 144.6 MB  | #####4     |  55%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####1      |  41%
#
#
#
#
#
#
#
# libcusolver-dev-11.4 | 94.1 MB   | #########9 | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####5     |  55%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####2      |  42%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####5     |  56%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####2      |  43%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####6     |  56%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####3      |  44%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####6     |  57%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########## | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####7     |  58%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####5      |  45%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #####8     |  58%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####6      |  46%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####6      |  47%
# libcufft-dev-10.9.0. | 144.6 MB  | #####8     |  59%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####7      |  48%
# libcufft-dev-10.9.0. | 144.6 MB  | #####9     |  60%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.3.0     | 7.0 MB    | ########## | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####8      |  48%
# libcufft-dev-10.9.0. | 144.6 MB  | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####9      |  49%
# libcufft-dev-10.9.0. | 144.6 MB  | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
# libcufft-dev-10.9.0. | 144.6 MB  | ######2    |  62%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   7%
# libcufft-dev-10.9.0. | 144.6 MB  | ######3    |  63%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
# libcufft-dev-10.9.0. | 144.6 MB  | ######3    |  64%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ######4    |  65%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ######5    |  66%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####2     |  53%
# libcufft-dev-10.9.0. | 144.6 MB  | ######6    |  67%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####3     |  54%
# libcufft-dev-10.9.0. | 144.6 MB  | ######7    |  68%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####4     |  54%
# libcufft-dev-10.9.0. | 144.6 MB  | ######8    |  68%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####5     |  55%
# libcufft-dev-10.9.0. | 144.6 MB  | ######9    |  69%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####5     |  56%
# libcufft-dev-10.9.0. | 144.6 MB  | #######    |  70%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #######1   |  71%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####7     |  57%
# libcufft-dev-10.9.0. | 144.6 MB  | #######2   |  72%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####7     |  58%
# libcufft-dev-10.9.0. | 144.6 MB  | #######3   |  73%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
# libcufft-dev-10.9.0. | 144.6 MB  | #######4   |  74%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####8     |  58%
# libcufft-dev-10.9.0. | 144.6 MB  | #######4   |  75%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####9     |  59%
# libcufft-dev-10.9.0. | 144.6 MB  | #######5   |  76%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #####9     |  60%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #######7   |  77%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######     |  60%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #######8   |  78%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######     |  61%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #######9   |  79%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######1    |  61%
# libcufft-dev-10.9.0. | 144.6 MB  | #######9   |  80%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######1    |  62%
# libcufft-dev-10.9.0. | 144.6 MB  | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######2    |  62%
# libcufft-dev-10.9.0. | 144.6 MB  | ########2  |  83%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######2    |  63%
# libcufft-dev-10.9.0. | 144.6 MB  | ########3  |  84%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######3    |  63%
# libcufft-dev-10.9.0. | 144.6 MB  | ########4  |  84%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######3    |  64%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | ########5  |  85%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######4    |  64%
# libcufft-dev-10.9.0. | 144.6 MB  | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######4    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
# libcufft-dev-10.9.0. | 144.6 MB  | ########7  |  87%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######5    |  65%
# libcufft-dev-10.9.0. | 144.6 MB  | ########8  |  89%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######5    |  66%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
# libcufft-dev-10.9.0. | 144.6 MB  | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######6    |  66%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #########1 |  91%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######6    |  66%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #########2 |  93%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######6    |  67%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #########3 |  94%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |   9%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #########4 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcufft-dev-10.9.0. | 144.6 MB  | #########5 |  96%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######8    |  68%
# libcufft-dev-10.9.0. | 144.6 MB  | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######8    |  69%
# libcufft-dev-10.9.0. | 144.6 MB  | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | 9          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #          |  10%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #######    |  71%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #          |  10%
#
#
#
#
#
# ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | ########9  |  89%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | ########9  |  90%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | ########9  |  90%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########  |  90%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########  |  90%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########  |  91%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########  |  91%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########1 |  91%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########1 |  91%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########1 |  92%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########1 |  92%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########2 |  92%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########2 |  92%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########2 |  93%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########2 |  93%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########3 |  93%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########3 |  93%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########3 |  94%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########3 |  94%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########4 |  94%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########4 |  94%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########4 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########4 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########5 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########5 |  95%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########5 |  96%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########5 |  96%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########6 |  96%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########6 |  96%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########6 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########6 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########7 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########7 |  97%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########7 |  98%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########7 |  98%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  98%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  98%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  98%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########8 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########9 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########9 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########9 |  99%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########9 | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | #########9 | 100%
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | ########## | 100%
#
#
#
#
# pytorch-2.3.0        | 1.39 GB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda-client==1.11.0=py39haa95532_0
#   - defaults/win-64::anaconda==custom=py39_2
#   - defaults/win-64::anaconda-navigator==2.4.2=py39haa95532_0
#   - defaults/win-64::anaconda-project==0.11.1=py39haa95532_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/noarch::arrow==1.2.2=pyhd3eb1b0_0
#   - defaults/win-64::astroid==2.11.7=py39haa95532_0
#   - defaults/win-64::astropy==5.1=py39h080aedc_0
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_1
#   - defaults/win-64::black==22.6.0=py39haa95532_0
#   - defaults/win-64::bokeh==2.4.3=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.5=py39h080aedc_0
#   - defaults/win-64::cartopy==0.18.0=py39h80a4efb_1
#   - defaults/win-64::click==8.0.4=py39haa95532_0
#   - defaults/noarch::click-plugins==1.1.1=pyhd3eb1b0_0
#   - defaults/win-64::cligj==0.7.2=py39haa95532_0
#   - defaults/win-64::colorcet==3.0.0=py39haa95532_0
#   - defaults/win-64::conda==23.3.1=py39haa95532_0
#   - defaults/win-64::conda-build==3.22.0=py39haa95532_0
#   - defaults/win-64::conda-repo-cli==1.0.41=py39haa95532_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/win-64::daal4py==2021.6.0=py39h757b272_1
#   - defaults/win-64::dask==2022.7.0=py39haa95532_0
#   - defaults/win-64::dask-core==2022.7.0=py39haa95532_0
#   - defaults/win-64::datashader==0.14.1=py39haa95532_0
#   - defaults/win-64::datashape==0.5.4=py39haa95532_1
#   - defaults/win-64::distributed==2022.7.0=py39haa95532_0
#   - defaults/win-64::fiona==1.8.22=py39hac22706_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/win-64::flask-compress==1.13=py39haa95532_0
#   - defaults/win-64::folium==0.14.0=py39haa95532_0
#   - defaults/win-64::gdal==3.0.2=py39hb978731_4
#   - defaults/win-64::gensim==4.1.2=py39hd77b12b_0
#   - defaults/win-64::geopandas==0.12.2=py39haa95532_0
#   - defaults/win-64::geopandas-base==0.12.2=py39haa95532_0
#   - defaults/win-64::h5py==3.7.0=py39h3de5c98_0
#   - defaults/win-64::holoviews==1.15.0=py39haa95532_0
#   - defaults/win-64::hvplot==0.8.0=py39haa95532_0
#   - defaults/win-64::imagecodecs==2021.8.26=py39hc0a7faf_1
#   - defaults/win-64::imageio==2.19.3=py39haa95532_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/win-64::ipykernel==6.15.2=py39haa95532_0
#   - defaults/win-64::ipython==7.31.1=py39haa95532_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_8
#   - defaults/win-64::jupyterlab==3.4.4=py39haa95532_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.3=pyhd3eb1b0_0
#   - defaults/win-64::jupyter_server==1.18.1=py39haa95532_0
#   - defaults/win-64::mapclassify==2.5.0=py39haa95532_0
#   - defaults/win-64::matplotlib==3.5.2=py39haa95532_0
#   - defaults/win-64::matplotlib-base==3.5.2=py39hd77b12b_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/win-64::navigator-updater==0.3.0=py39haa95532_0
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/win-64::nbconvert==6.4.4=py39haa95532_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.4.12=py39haa95532_0
#   - defaults/win-64::numba==0.55.1=py39hf11a4ad_0
#   - defaults/win-64::numexpr==2.8.3=py39hb80d3ca_0
#   - defaults/win-64::numpy==1.21.5=py39h7a0a035_3
#   - defaults/win-64::numpydoc==1.4.0=py39haa95532_0
#   - defaults/win-64::pandas==1.4.4=py39hd77b12b_0
#   - defaults/win-64::panel==0.13.1=py39haa95532_0
#   - defaults/win-64::patsy==0.5.2=py39haa95532_1
#   - defaults/win-64::plotly==5.9.0=py39haa95532_0
#   - defaults/win-64::pyct==0.4.8=py39haa95532_1
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/win-64::pylint==2.14.5=py39haa95532_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::pytables==3.6.1=py39h56d22b6_1
#   - defaults/win-64::pytest==7.1.2=py39haa95532_0
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::python-lsp-server==1.3.3=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.3.0=py39h2bbff1b_0
#   - defaults/noarch::qtconsole==5.2.2=pyhd3eb1b0_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/win-64::scikit-image==0.19.2=py39hf11a4ad_0
#   - defaults/win-64::scikit-learn-intelex==2021.6.0=py39haa95532_0
#   - defaults/win-64::scipy==1.9.1=py39he11b74f_0
#   - defaults/win-64::scrapy==2.6.2=py39haa95532_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::shapely==2.0.1=py39hd7f5953_0
#   - defaults/win-64::sphinx==5.0.2=py39haa95532_0
#   - defaults/win-64::spyder==5.2.2=py39haa95532_1
#   - defaults/win-64::spyder-kernels==2.2.1=py39haa95532_0
#   - defaults/win-64::statsmodels==0.13.2=py39h2bbff1b_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
#   - defaults/win-64::twisted==22.2.0=py39h2bbff1b_1
#   - defaults/win-64::typing-extensions==4.3.0=py39haa95532_0
#   - defaults/win-64::widgetsnbextension==3.5.2=py39haa95532_0
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
#   - defaults/win-64::_anaconda_depends==2022.10=py39_2
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda-client==1.11.0=py39haa95532_0
#   - defaults/win-64::anaconda==custom=py39_2
#   - defaults/win-64::anaconda-navigator==2.4.2=py39haa95532_0
#   - defaults/win-64::anaconda-project==0.11.1=py39haa95532_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/noarch::arrow==1.2.2=pyhd3eb1b0_0
#   - defaults/win-64::astroid==2.11.7=py39haa95532_0
#   - defaults/win-64::astropy==5.1=py39h080aedc_0
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_1
#   - defaults/win-64::black==22.6.0=py39haa95532_0
#   - defaults/win-64::bokeh==2.4.3=py39haa95532_0
#   - defaults/win-64::bottleneck==1.3.5=py39h080aedc_0
#   - defaults/win-64::cartopy==0.18.0=py39h80a4efb_1
#   - defaults/win-64::click==8.0.4=py39haa95532_0
#   - defaults/noarch::click-plugins==1.1.1=pyhd3eb1b0_0
#   - defaults/win-64::cligj==0.7.2=py39haa95532_0
#   - defaults/win-64::colorcet==3.0.0=py39haa95532_0
#   - defaults/win-64::conda==23.3.1=py39haa95532_0
#   - defaults/win-64::conda-build==3.22.0=py39haa95532_0
#   - defaults/win-64::conda-repo-cli==1.0.41=py39haa95532_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/win-64::daal4py==2021.6.0=py39h757b272_1
#   - defaults/win-64::dask==2022.7.0=py39haa95532_0
#   - defaults/win-64::dask-core==2022.7.0=py39haa95532_0
#   - defaults/win-64::datashader==0.14.1=py39haa95532_0
#   - defaults/win-64::datashape==0.5.4=py39haa95532_1
#   - defaults/win-64::distributed==2022.7.0=py39haa95532_0
#   - defaults/win-64::fiona==1.8.22=py39hac22706_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/win-64::flask-compress==1.13=py39haa95532_0
#   - defaults/win-64::folium==0.14.0=py39haa95532_0
#   - defaults/win-64::gdal==3.0.2=py39hb978731_4
#   - defaults/win-64::gensim==4.1.2=py39hd77b12b_0
#   - defaults/win-64::geopandas==0.12.2=py39haa95532_0
#   - defaults/win-64::geopandas-base==0.12.2=py39haa95532_0
#   - defaults/win-64::h5py==3.7.0=py39h3de5c98_0
#   - defaults/win-64::holoviews==1.15.0=py39haa95532_0
#   - defaults/win-64::hvplot==0.8.0=py39haa95532_0
#   - defaults/win-64::imagecodecs==2021.8.26=py39hc0a7faf_1
#   - defaults/win-64::imageio==2.19.3=py39haa95532_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/win-64::ipykernel==6.15.2=py39haa95532_0
#   - defaults/win-64::ipython==7.31.1=py39haa95532_1
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/win-64::jupyter==1.0.0=py39haa95532_8
#   - defaults/win-64::jupyterlab==3.4.4=py39haa95532_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/noarch::jupyter_console==6.4.3=pyhd3eb1b0_0
#   - defaults/win-64::jupyter_server==1.18.1=py39haa95532_0
#   - defaults/win-64::mapclassify==2.5.0=py39haa95532_0
#   - defaults/win-64::matplotlib==3.5.2=py39haa95532_0
#   - defaults/win-64::matplotlib-base==3.5.2=py39hd77b12b_0
#   - defaults/win-64::mkl_fft==1.3.1=py39h277e83a_0
#   - defaults/win-64::mkl_random==1.2.2=py39hf11a4ad_0
#   - defaults/win-64::navigator-updater==0.3.0=py39haa95532_0
#   - defaults/noarch::nbclassic==0.3.5=pyhd3eb1b0_0
#   - defaults/win-64::nbconvert==6.4.4=py39haa95532_0
#   - defaults/noarch::nltk==3.7=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.4.12=py39haa95532_0
#   - defaults/win-64::numba==0.55.1=py39hf11a4ad_0
#   - defaults/win-64::numexpr==2.8.3=py39hb80d3ca_0
#   - defaults/win-64::numpy==1.21.5=py39h7a0a035_3
#   - defaults/win-64::numpydoc==1.4.0=py39haa95532_0
#   - defaults/win-64::pandas==1.4.4=py39hd77b12b_0
#   - defaults/win-64::panel==0.13.1=py39haa95532_0
#   - defaults/win-64::patsy==0.5.2=py39haa95532_1
#   - defaults/win-64::plotly==5.9.0=py39haa95532_0
#   - defaults/win-64::pyct==0.4.8=py39haa95532_1
#   - defaults/win-64::pyerfa==2.0.0=py39h2bbff1b_0
#   - defaults/win-64::pylint==2.14.5=py39haa95532_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::pytables==3.6.1=py39h56d22b6_1
#   - defaults/win-64::pytest==7.1.2=py39haa95532_0
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::python-lsp-server==1.3.3=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.3.0=py39h2bbff1b_0
#   - defaults/noarch::qtconsole==5.2.2=pyhd3eb1b0_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/win-64::scikit-image==0.19.2=py39hf11a4ad_0
#   - defaults/win-64::scikit-learn-intelex==2021.6.0=py39haa95532_0
#   - defaults/win-64::scipy==1.9.1=py39he11b74f_0
#   - defaults/win-64::scrapy==2.6.2=py39haa95532_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::shapely==2.0.1=py39hd7f5953_0
#   - defaults/win-64::sphinx==5.0.2=py39haa95532_0
#   - defaults/win-64::spyder==5.2.2=py39haa95532_1
#   - defaults/win-64::spyder-kernels==2.2.1=py39haa95532_0
#   - defaults/win-64::statsmodels==0.13.2=py39h2bbff1b_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
#   - defaults/win-64::twisted==22.2.0=py39h2bbff1b_1
#   - defaults/win-64::typing-extensions==4.3.0=py39haa95532_0
#   - defaults/win-64::widgetsnbextension==3.5.2=py39haa95532_0
#   - defaults/noarch::xarray==0.20.1=pyhd3eb1b0_1
#   - defaults/win-64::_anaconda_depends==2022.10=py39_2
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39haa95532_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.9.1
#
#
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'tqdm' is a dependency of conda and cannot be removed from
# conda's operating environment.

# %%
import os
import streamlit as st
import pdfplumber
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import openai
from langdetect import detect
from nltk.tokenize import sent_tokenize

# Initialize OpenAI API key (use your key)
openai.api_key = os.getenv("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")

# Load the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Streamlit UI for the chatbot
st.set_page_config(page_title="Document-Based Chatbot", layout="wide")
st.title("Document-Based Question Answering Chatbot")
st.markdown("Ask your question, and the chatbot will retrieve answers from stored documents.")

# Sidebar for translation option
with st.sidebar:
    st.header("Translation Options")
    translate_option = st.radio("Would you like to translate responses?", ('No', 'Yes'))
    target_language = st.selectbox("Select target language", ['French', 'Spanish', 'German']) if translate_option == 'Yes' else None

# Path to folder where your PDFs are stored
folder_path = 'C:/Users/Ishtiyak/Desktop/chatbot/documents'

# Function to extract text from PDFs in the folder
@st.cache
def extract_text_from_pdfs(folder_path):
    documents = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf'):
            file_path = os.path.join(folder_path, filename)
            with pdfplumber.open(file_path) as pdf:
                full_text = ""
                for page in pdf.pages:
                    full_text += page.extract_text()
                documents[filename] = full_text
    return documents

# Function to chunk the text into smaller segments
def chunk_text_for_all_docs(documents, max_tokens=500):
    all_chunks = {}
    for filename, text in documents.items():
        sentences = sent_tokenize(text)
        chunks = []
        chunk = []
        tokens_count = 0
        for sentence in sentences:
            tokens = len(sentence.split())
            if tokens_count + tokens > max_tokens:
                chunks.append(" ".join(chunk))
                chunk = []
                tokens_count = 0
            chunk.append(sentence)
            tokens_count += tokens
        if chunk:
            chunks.append(" ".join(chunk))
        all_chunks[filename] = chunks
    return all_chunks

# Function to generate embeddings
def generate_embeddings_for_all_docs(all_chunks):
    all_embeddings = {}
    embedding_ids = []
    chunk_count = 0
    for filename, chunks in all_chunks.items():
        embeddings = model.encode(chunks, convert_to_tensor=False)
        all_embeddings[filename] = embeddings
        for i, chunk in enumerate(chunks):
            embedding_ids.append(f"{filename}-chunk-{i}")
            chunk_count += 1
    return all_embeddings, embedding_ids

# Function to create FAISS index
def create_faiss_index(embeddings):
    dimension = embeddings[next(iter(embeddings))][0].shape[0]  # Embedding size
    index = faiss.IndexFlatL2(dimension)  # L2 distance index
    all_embedding_list = []
    for embedding_list in embeddings.values():
        all_embedding_list.extend(embedding_list)
    index.add(np.array(all_embedding_list))
    return index

# Function to query FAISS
def query_faiss(query, all_chunks, index, embedding_ids, top_k=3):
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding), top_k)
    retrieved_chunks = [all_chunks[embedding_ids[i].split('-chunk-')[0]][int(embedding_ids[i].split('-chunk-')[-1])] for i in I[0]]
    return retrieved_chunks

# Function to generate a response from GPT-3.5
def generate_response_with_context(query, retrieved_chunks):
    prompt = f"User query: {query}\n\nRelevant information from documents:\n{retrieved_chunks}"
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=200
    )
    return response['choices'][0]['message']['content'].strip()

# Function to translate the response
def translate_text(text, target_language):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": f"Translate this text to {target_language}."},
            {"role": "user", "content": text}
        ],
        max_tokens=100
    )
    return response['choices'][0]['message']['content'].strip()

# Main section to process PDFs and answer questions
with st.spinner('Processing documents...'):
    documents = extract_text_from_pdfs(folder_path)
    all_chunks = chunk_text_for_all_docs(documents)
    all_embeddings, embedding_ids = generate_embeddings_for_all_docs(all_chunks)
    index = create_faiss_index(all_embeddings)
    st.success('Documents processed successfully!')

# Continuous Chat Interface
user_query = st.text_input("Enter your query:")

if st.button("Submit Query") and user_query:
    retrieved_chunks = query_faiss(user_query, all_chunks, index, embedding_ids)
    response = generate_response_with_context(user_query, retrieved_chunks)
    
    st.write("Response:")
    st.write(response)

    # Handle translation if enabled
    if translate_option == 'Yes' and target_language:
        translated_response = translate_text(response, target_language)
        st.write(f"Translated Response ({target_language}):")
        st.write(translated_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8592\3051157846.py in <module>
#       4 import faiss
#       5 import numpy as np
# ----> 6 from sentence_transformers import SentenceTransformer
#       7 import openai
#       8 from langdetect import detect
#
# ~\anaconda3\lib\site-packages\sentence_transformers\__init__.py in <module>
#       7 import os
#       8
# ----> 9 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#      10 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      11 from sentence_transformers.LoggingHandler import LoggingHandler
#
# ~\anaconda3\lib\site-packages\sentence_transformers\cross_encoder\__init__.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from .CrossEncoder import CrossEncoder
#       4
#       5 __all__ = ["CrossEncoder"]
#
# ~\anaconda3\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py in <module>
#       7
#       8 import numpy as np
# ----> 9 import torch
#      10 from torch import Tensor, nn
#      11 from torch.optim import Optimizer
#
# ~\anaconda3\lib\site-packages\torch\__init__.py in <module>
#     762
#     763 __name, __obj = '', None
# --> 764 for __name in dir(_C):
#     765     if __name[0] != '_' and not __name.endswith('Base'):
#     766         __all__.append(__name)
#
# NameError: name '_C' is not defined

# %%
# !streamlit run app.py
